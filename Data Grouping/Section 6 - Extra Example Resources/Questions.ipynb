# %% [markdown]
# # Extra Examples - Merging
#
# Heres a dataset dumped directly from a database, so we need to stitch it together ourselves.
# https://www.kaggle.com/uciml/restaurant-data-with-consumer-ratings
#
# The dataset comes with a README file that outlines where everything comes from which might help.
#
# Lets try to:
#
# 1. Merge all restaurant data
# 2. Merge all user data
# 3. Merge restaurant data and user data together using user ratings
# 4. Realise that we've merged too much, and merge user ratings + user profile + geoplaces
# 5. Use some groupby power and determine the top five restaurants in the dataset

# %%
import pandas as pd
import os

files = [f for f in os.listdir() if f.endswith(".csv")]
print(files)
# Out:
# ['chefmozaccepts.csv', 'chefmozcuisine.csv', 'chefmozhours4.csv', 'chefmozparking.csv', 'geoplaces2.csv', 'rating_final.csv', 'usercuisine.csv', 'userpayment.csv', 'userprofile.csv']

# %% [markdown]
# ## Merging restaurant data

# %%
# your code here
df = pd.read_csv(files[0])
files.remove(files[0])
for file in files:
    dfs = pd.read_csv(file)
    if 'placeID' not in dfs.columns:
        df = df.merge(dfs, on='userID')
    else:
        df = df.merge(dfs, on='placeID')
    print(file)
    display(df.head())
# Out:
# chefmozcuisine.csv
#    placeID             Rpayment Rcuisine
# 0   135110                 cash  Spanish
# 1   135110                 VISA  Spanish
# 2   135110  MasterCard-Eurocard  Spanish
# 3   135110     American_Express  Spanish
# 4   135110     bank_debit_cards  Spanish
# chefmozhours4.csv
#    placeID Rpayment Rcuisine         hours                  days
# 0   135110     cash  Spanish  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 1   135110     cash  Spanish  00:00-00:00;                  Sat;
# 2   135110     cash  Spanish  00:00-00:00;                  Sun;
# 3   135110     VISA  Spanish  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 4   135110     VISA  Spanish  00:00-00:00;                  Sat;
# chefmozparking.csv
#    placeID Rpayment Rcuisine         hours                  days parking_lot
# 0   135110     cash  Spanish  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;        none
# 1   135110     cash  Spanish  00:00-00:00;                  Sat;        none
# 2   135110     cash  Spanish  00:00-00:00;                  Sun;        none
# 3   135110     VISA  Spanish  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;        none
# 4   135110     VISA  Spanish  00:00-00:00;                  Sat;        none
# geoplaces2.csv
#    placeID Rpayment Rcuisine         hours                  days parking_lot  \
# 0   135109     cash  Italian  08:00-21:00;  Mon;Tue;Wed;Thu;Fri;        none
# 1   135109     cash  Italian  08:00-21:00;                  Sat;        none
# 2   135109     cash  Italian  08:00-21:00;                  Sun;        none
# 3   135106     cash  Mexican  18:00-23:30;  Mon;Tue;Wed;Thu;Fri;        none
# 4   135106     cash  Mexican  18:00-23:30;                  Sat;        none
#
#     latitude   longitude                                     the_geom_meter  \
# 0  18.921785  -99.235350  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 1  18.921785  -99.235350  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 2  18.921785  -99.235350  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 3  22.149709 -100.976093  0101000020957F0000649D6F21634858C119AE9BF528A3...
# 4  22.149709 -100.976093  0101000020957F0000649D6F21634858C119AE9BF528A3...
#
#                          name  ...    alcohol   smoking_area dress_code  \
# 0                   Paniroles  ...  Wine-Beer  not permitted   informal
# 1                   Paniroles  ...  Wine-Beer  not permitted   informal
# 2                   Paniroles  ...  Wine-Beer  not permitted   informal
# 3  El Rinc�n de San Francisco  ...  Wine-Beer    only at bar   informal
# 4  El Rinc�n de San Francisco  ...  Wine-Beer    only at bar   informal
#
#       accessibility   price url Rambience franchise    area other_services
# 0  no_accessibility  medium   ?     quiet         f  closed       Internet
# 1  no_accessibility  medium   ?     quiet         f  closed       Internet
# 2  no_accessibility  medium   ?     quiet         f  closed       Internet
# 3         partially  medium   ?  familiar         f    open           none
# 4         partially  medium   ?  familiar         f    open           none
#
# [5 rows x 26 columns]
# rating_final.csv
#    placeID Rpayment Rcuisine         hours                  days parking_lot  \
# 0   135109     cash  Italian  08:00-21:00;  Mon;Tue;Wed;Thu;Fri;        none
# 1   135109     cash  Italian  08:00-21:00;  Mon;Tue;Wed;Thu;Fri;        none
# 2   135109     cash  Italian  08:00-21:00;  Mon;Tue;Wed;Thu;Fri;        none
# 3   135109     cash  Italian  08:00-21:00;  Mon;Tue;Wed;Thu;Fri;        none
# 4   135109     cash  Italian  08:00-21:00;                  Sat;        none
#
#     latitude  longitude                                     the_geom_meter  \
# 0  18.921785  -99.23535  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 1  18.921785  -99.23535  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 2  18.921785  -99.23535  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 3  18.921785  -99.23535  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 4  18.921785  -99.23535  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
#
#         name  ...   price url Rambience franchise    area other_services  \
# 0  Paniroles  ...  medium   ?     quiet         f  closed       Internet
# 1  Paniroles  ...  medium   ?     quiet         f  closed       Internet
# 2  Paniroles  ...  medium   ?     quiet         f  closed       Internet
# 3  Paniroles  ...  medium   ?     quiet         f  closed       Internet
# 4  Paniroles  ...  medium   ?     quiet         f  closed       Internet
#
#   userID rating food_rating service_rating
# 0  U1030      0           0              0
# 1  U1020      2           2              1
# 2  U1051      1           1              1
# 3  U1041      1           2              1
# 4  U1030      0           0              0
#
# [5 rows x 30 columns]
# usercuisine.csv
#    placeID Rpayment Rcuisine_x         hours                  days  \
# 0   135109     cash    Italian  08:00-21:00;  Mon;Tue;Wed;Thu;Fri;
# 1   135109     cash    Italian  08:00-21:00;                  Sat;
# 2   135109     cash    Italian  08:00-21:00;                  Sun;
# 3   135088     cash  Cafeteria  09:00-16:00;  Mon;Tue;Wed;Thu;Fri;
# 4   135088     cash  Cafeteria  00:00-00:00;                  Sat;
#
#   parking_lot   latitude  longitude  \
# 0        none  18.921785  -99.23535
# 1        none  18.921785  -99.23535
# 2        none  18.921785  -99.23535
# 3      public  18.876011  -99.21989
# 4      public  18.876011  -99.21989
#
#                                       the_geom_meter               name  ...  \
# 0  0101000020957F0000A6BF695F136F5AC1DADF87B20556...          Paniroles  ...
# 1  0101000020957F0000A6BF695F136F5AC1DADF87B20556...          Paniroles  ...
# 2  0101000020957F0000A6BF695F136F5AC1DADF87B20556...          Paniroles  ...
# 3  0101000020957F0000E14AD4DBC7765AC1F7B33C85B153...  Cafeteria cenidet  ...
# 4  0101000020957F0000E14AD4DBC7765AC1F7B33C85B153...  Cafeteria cenidet  ...
#
#                   url Rambience franchise    area other_services userID  \
# 0                   ?     quiet         f  closed       Internet  U1030
# 1                   ?     quiet         f  closed       Internet  U1030
# 2                   ?     quiet         f  closed       Internet  U1030
# 3  www.cenidet.edu.mx     quiet         f  closed           none  U1030
# 4  www.cenidet.edu.mx     quiet         f  closed           none  U1030
#
#   rating food_rating service_rating Rcuisine_y
# 0      0           0              0    Mexican
# 1      0           0              0    Mexican
# 2      0           0              0    Mexican
# 3      1           0              1    Mexican
# 4      1           0              1    Mexican
#
# [5 rows x 31 columns]
# userpayment.csv
#    placeID Rpayment Rcuisine_x         hours                  days  \
# 0   135109     cash    Italian  08:00-21:00;  Mon;Tue;Wed;Thu;Fri;
# 1   135109     cash    Italian  08:00-21:00;                  Sat;
# 2   135109     cash    Italian  08:00-21:00;                  Sun;
# 3   135088     cash  Cafeteria  09:00-16:00;  Mon;Tue;Wed;Thu;Fri;
# 4   135088     cash  Cafeteria  00:00-00:00;                  Sat;
#
#   parking_lot   latitude  longitude  \
# 0        none  18.921785  -99.23535
# 1        none  18.921785  -99.23535
# 2        none  18.921785  -99.23535
# 3      public  18.876011  -99.21989
# 4      public  18.876011  -99.21989
#
#                                       the_geom_meter               name  ...  \
# 0  0101000020957F0000A6BF695F136F5AC1DADF87B20556...          Paniroles  ...
# 1  0101000020957F0000A6BF695F136F5AC1DADF87B20556...          Paniroles  ...
# 2  0101000020957F0000A6BF695F136F5AC1DADF87B20556...          Paniroles  ...
# 3  0101000020957F0000E14AD4DBC7765AC1F7B33C85B153...  Cafeteria cenidet  ...
# 4  0101000020957F0000E14AD4DBC7765AC1F7B33C85B153...  Cafeteria cenidet  ...
#
#   Rambience franchise    area other_services userID rating food_rating  \
# 0     quiet         f  closed       Internet  U1030      0           0
# 1     quiet         f  closed       Internet  U1030      0           0
# 2     quiet         f  closed       Internet  U1030      0           0
# 3     quiet         f  closed           none  U1030      1           0
# 4     quiet         f  closed           none  U1030      1           0
#
#   service_rating Rcuisine_y Upayment
# 0              0    Mexican     cash
# 1              0    Mexican     cash
# 2              0    Mexican     cash
# 3              1    Mexican     cash
# 4              1    Mexican     cash
#
# [5 rows x 32 columns]
# userprofile.csv
#    placeID Rpayment Rcuisine_x         hours                  days  \
# 0   135109     cash    Italian  08:00-21:00;  Mon;Tue;Wed;Thu;Fri;
# 1   135109     cash    Italian  08:00-21:00;                  Sat;
# 2   135109     cash    Italian  08:00-21:00;                  Sun;
# 3   135088     cash  Cafeteria  09:00-16:00;  Mon;Tue;Wed;Thu;Fri;
# 4   135088     cash  Cafeteria  00:00-00:00;                  Sat;
#
#   parking_lot  latitude_x  longitude_x  \
# 0        none   18.921785    -99.23535
# 1        none   18.921785    -99.23535
# 2        none   18.921785    -99.23535
# 3      public   18.876011    -99.21989
# 4      public   18.876011    -99.21989
#
#                                       the_geom_meter               name  ...  \
# 0  0101000020957F0000A6BF695F136F5AC1DADF87B20556...          Paniroles  ...
# 1  0101000020957F0000A6BF695F136F5AC1DADF87B20556...          Paniroles  ...
# 2  0101000020957F0000A6BF695F136F5AC1DADF87B20556...          Paniroles  ...
# 3  0101000020957F0000E14AD4DBC7765AC1F7B33C85B153...  Cafeteria cenidet  ...
# 4  0101000020957F0000E14AD4DBC7765AC1F7B33C85B153...  Cafeteria cenidet  ...
#
#          hijos birth_year      interest  personality  religion activity  \
# 0  independent       1991  eco-friendly  hard-worker  Catholic  student
# 1  independent       1991  eco-friendly  hard-worker  Catholic  student
# 2  independent       1991  eco-friendly  hard-worker  Catholic  student
# 3  independent       1991  eco-friendly  hard-worker  Catholic  student
# 4  independent       1991  eco-friendly  hard-worker  Catholic  student
#
#    color weight  budget height
# 0  black     64  medium   1.75
# 1  black     64  medium   1.75
# 2  black     64  medium   1.75
# 3  black     64  medium   1.75
# 4  black     64  medium   1.75
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Merging User data

# %%
# your code here
df_user = None
for file in files:
    if file.startswith('user'):
        df_temp = pd.read_csv(file)
        if df_user is not None:
            df_user = df_user.merge(df_temp, on='userID')
        else:
            df_user = df_temp.copy()
        display(df_user.head())
# Out:
#   userID          Rcuisine
# 0  U1001          American
# 1  U1002           Mexican
# 2  U1003           Mexican
# 3  U1004            Bakery
# 4  U1004  Breakfast-Brunch
# here we go
#   userID  Rcuisine          Upayment
# 0  U1001  American              cash
# 1  U1002   Mexican              cash
# 2  U1003   Mexican              cash
# 3  U1004    Bakery              cash
# 4  U1004    Bakery  bank_debit_cards
# here we go
#   userID  Rcuisine          Upayment   latitude   longitude smoker  \
# 0  U1001  American              cash  22.139997 -100.978803  false
# 1  U1002   Mexican              cash  22.150087 -100.983325  false
# 2  U1003   Mexican              cash  22.119847 -100.946527  false
# 3  U1004    Bakery              cash  18.867000  -99.183000  false
# 4  U1004    Bakery  bank_debit_cards  18.867000  -99.183000  false
#
#       drink_level dress_preference ambience transport  ...        hijos  \
# 0      abstemious         informal   family   on foot  ...  independent
# 1      abstemious         informal   family    public  ...  independent
# 2  social drinker           formal   family    public  ...  independent
# 3      abstemious         informal   family    public  ...  independent
# 4      abstemious         informal   family    public  ...  independent
#
#   birth_year    interest          personality  religion      activity  color  \
# 0       1989     variety    thrifty-protector      none       student  black
# 1       1990  technology  hunter-ostentatious  Catholic       student    red
# 2       1989        none          hard-worker  Catholic       student   blue
# 3       1940     variety          hard-worker      none  professional  green
# 4       1940     variety          hard-worker      none  professional  green
#
#   weight  budget height
# 0     69  medium   1.77
# 1     40     low   1.87
# 2     60     low   1.69
# 3     44  medium   1.53
# 4     44  medium   1.53
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Merging User ratings as well

# %%
# your code here
user_rating = pd.read_csv('rating_final.csv')
user_rating = user_rating.merge(df_user, on='userID')
user_rating = user_rating.merge(df,on='userID')
user_rating.head()
# Out:
#   userID  placeID_x  rating_x  food_rating_x  service_rating_x Rcuisine  \
# 0  U1077     135085         2              2                 2  Mexican
# 1  U1077     135085         2              2                 2  Mexican
# 2  U1077     135085         2              2                 2  Mexican
# 3  U1077     135085         2              2                 2  Mexican
# 4  U1077     135085         2              2                 2  Mexican
#
#   Upayment_x   latitude  longitude smoker_x  ... hijos_y birth_year_y  \
# 0       VISA  22.156469 -100.98554    false  ...    kids         1987
# 1       VISA  22.156469 -100.98554    false  ...    kids         1987
# 2       VISA  22.156469 -100.98554    false  ...    kids         1987
# 3       VISA  22.156469 -100.98554    false  ...    kids         1987
# 4       VISA  22.156469 -100.98554    false  ...    kids         1987
#
#    interest_y      personality_y religion_y activity_y  color_y weight_y  \
# 0  technology  thrifty-protector   Catholic    student     blue       65
# 1  technology  thrifty-protector   Catholic    student     blue       65
# 2  technology  thrifty-protector   Catholic    student     blue       65
# 3  technology  thrifty-protector   Catholic    student     blue       65
# 4  technology  thrifty-protector   Catholic    student     blue       65
#
#   budget_y height_y
# 0   medium     1.71
# 1   medium     1.71
# 2   medium     1.71
# 3   medium     1.71
# 4   medium     1.71
#
# [5 rows x 74 columns]

# %% [markdown]
# ## Merge Subsets

# %%
# your code here

# %% [markdown]
# ## Top 5 restaurants based off rating
#
# Note to answer this we didn't actually need the user profile data. But we might use it to remove votes from users that don't satisfy criteria (for example, we might want to make sure the user has been to multiple restaurants, or is a certain age, or doesnt have suspicious voting trends - aka giving everyone a one).

# %%
# your code here
