# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./Dataset/astronauts.csv')
df.head(2)
# Out:
#               Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1   Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
# 1  Solar Physics           NaN             NaN              1
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN
# ...

# %%
birthdate = pd.to_datetime(df['Birth Date'], format="%m/%d/%Y")
birthdate
# Out:
# 0     1967-05-17
# 1     1936-03-07
# 2     1946-03-03
# 3     1951-05-20
# 4     1930-01-20
#          ...
# 352   1956-08-23
# 353   1962-07-26
# 354   1932-02-07
# 355   1930-09-24
# 356   1962-06-29
# Name: Birth Date, Length: 357, dtype: datetime64[ns]

# %%
birthdate.dt.year
# Out:
# 0      1967
# 1      1936
# 2      1946
# 3      1951
# 4      1930
#        ...
# 352    1956
# 353    1962
# 354    1932
# 355    1930
# 356    1962
# Name: Birth Date, Length: 357, dtype: int64

# %%
zarya = pd.to_datetime("1998-11-20")
df['age_at_zarya'] = (zarya - birthdate).astype('timedelta64[Y]')
df.head(3)
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
# 2          US Military Academy; Princeton University          Engineering
#
#           Graduate Major Military Rank    Military Branch  Space Flights  \
# 0                Geology           NaN                NaN              2
# 1          Solar Physics           NaN                NaN              1
# 2  Aerospace Engineering       Colonel  US Army (Retired)              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# ...

# %%
df['birth'] = birthdate

# %% [markdown]
# # categoricals

# %%
df['Military Rank'].unique()
# Out:
# array([nan, 'Colonel', 'Lieutenant Colonel', 'Captain', 'Major General',
#        'Commander', 'Lieutenant Commander', 'Brigadier General', 'Major',
#        'Lieutenant General', 'Chief Warrant Officer', 'Rear Admiral',
#        'Vice Admiral'], dtype=object)

# %%
df['Military Rank'].dtype
# Out:
# dtype('O')

# %%
# replace Military Rank into catagorical data
df['Military Rank'] = df['Military Rank'].astype("category")

# %%
df['Military Rank'].unique()
# Out:
# [NaN, 'Colonel', 'Lieutenant Colonel', 'Captain', 'Major General', ..., 'Major', 'Lieutenant General', 'Chief Warrant Officer', 'Rear Admiral', 'Vice Admiral']
# Length: 13
# Categories (12, object): ['Brigadier General', 'Captain', 'Chief Warrant Officer', 'Colonel', ..., 'Major', 'Major General', 'Rear Admiral', 'Vice Admiral']

# %% [markdown]
# # Numeric / String Conversion

# %%
df.age_at_zarya.astype
# Out:
# <bound method NDFrame.astype of 0      31.0
# 1      62.0
# 2      52.0
# 3      47.0
# 4      68.0
#        ...
# 352    42.0
# 353    36.0
# 354    66.0
# 355    68.0
# 356    36.0
# Name: age_at_zarya, Length: 357, dtype: float64>

# %%
df.age_at_zarya.astype('float').astype('int')
# Out:
# 0      31
# 1      62
# 2      52
# 3      47
# 4      68
#        ..
# 352    42
# 353    36
# 354    66
# 355    68
# 356    36
# Name: age_at_zarya, Length: 357, dtype: int32

# %% [markdown]
# # Adding rows

# %%
df2 = df.loc[1:3,:]
df2.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
#
#                                          Alma Mater  Undergraduate Major  \
# 1  Montana State University; University of Colorado  Engineering Physics
# 2         US Military Academy; Princeton University          Engineering
# 3                      University of Missouri-Rolla  Applied Mathematics
#
#           Graduate Major  ...         Military Branch Space Flights  \
# 1          Solar Physics  ...                     NaN             1
# 2  Aerospace Engineering  ...       US Army (Retired)             2
# 3    Applied Mathematics  ...  US Air Force (Retired)             4
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# ...

# %%
# Adding rows
df2.append({'Name':'Tayyab'}, ignore_index=True)
# Out:
# C:\Users\muhammad.tayyab01\AppData\Local\Temp\ipykernel_23432\1157522418.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2.append({'Name':'Tayyab'}, ignore_index=True)
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 1  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 2   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 3            Tayyab     NaN    NaN      NaN        NaN            NaN    NaN
#
#                                          Alma Mater  Undergraduate Major  \
# 0  Montana State University; University of Colorado  Engineering Physics
# 1         US Military Academy; Princeton University          Engineering
# 2                      University of Missouri-Rolla  Applied Mathematics
# ...

# %% [markdown]
# ## adding cols

# %%
df2['test_col'] = 'Wojhojh'
df2
# Out:
# C:\Users\muhammad.tayyab01\AppData\Local\Temp\ipykernel_23432\3512501167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['test_col'] = 'Wojhojh'
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
#
#                                          Alma Mater  Undergraduate Major  \
# 1  Montana State University; University of Colorado  Engineering Physics
# 2         US Military Academy; Princeton University          Engineering
# ...

# %%
df.assign(some_col='value')
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %%
df.insert(0, 'First Name',df.Name.str.split(' ', 1, expand=True)[0])
df.head()
# Out:
#   First Name              Name    Year  Group   Status Birth Date  \
# 0     Joseph   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1      Loren    Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2      James  James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3     Thomas   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4       Buzz       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
#
#      Birth Place Gender                                         Alma Mater  \
# 0  Inglewood, CA   Male  University of California-Santa Barbara; Univer...
# 1   Lewiston, MT   Male   Montana State University; University of Colorado
# 2     Warsaw, NY   Male          US Military Academy; Princeton University
# 3  St. Louis, MO   Male                       University of Missouri-Rolla
# 4  Montclair, NJ   Male                           US Military Academy; MIT
#
#       Undergraduate Major  ...         Military Branch Space Flights  \
# ...

# %% [markdown]
# ## Transpose the dataframe

# %%
df2.T
# Out:
#                                                                     1  \
# Name                                                   Loren W. Acton
# Year                                                              NaN
# Group                                                             NaN
# Status                                                        Retired
# Birth Date                                                   3/7/1936
# Birth Place                                              Lewiston, MT
# Gender                                                           Male
# Alma Mater           Montana State University; University of Colorado
# Undergraduate Major                               Engineering Physics
# Graduate Major                                          Solar Physics
# Military Rank                                                     NaN
# Military Branch                                                   NaN
# ...
