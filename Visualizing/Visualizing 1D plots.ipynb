# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

df = pd.read_csv('./dataset/heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.age.plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(df.age,bins=30)
# Out:
# (array([ 1.,  0.,  0.,  6.,  0.,  5.,  7., 10., 16., 11., 15., 12.,  5.,
#         19., 13., 24., 19., 17., 33., 11., 19., 19.,  8., 16.,  4.,  7.,
#          3.,  0.,  1.,  2.]),
#  array([29. , 30.6, 32.2, 33.8, 35.4, 37. , 38.6, 40.2, 41.8, 43.4, 45. ,
#         46.6, 48.2, 49.8, 51.4, 53. , 54.6, 56.2, 57.8, 59.4, 61. , 62.6,
#         64.2, 65.8, 67.4, 69. , 70.6, 72.2, 73.8, 75.4, 77. ]),
#  <BarContainer object of 30 artists>)

# %%
fig,ax = plt.subplots()
ax.hist(df.trestbps, bins=20, histtype='step', label = 'trestbps')
ax.hist(df.thalach, bins=20, histtype='stepfilled', label = 'thalach',
        alpha=0.3, edgecolor='w')
ax.legend();

# %% [markdown]
# # Box Plot

# %%
df[['trestbps','thalach']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[['trestbps','thalach']].describe()
# Out:
#          trestbps     thalach
# count  303.000000  303.000000
# mean   131.623762  149.646865
# std     17.538143   22.905161
# min     94.000000   71.000000
# 25%    120.000000  133.500000
# 50%    130.000000  153.000000
# 75%    140.000000  166.000000
# max    200.000000  202.000000

# %% [markdown]
# # Violin Plot

# %%
fig, ax = plt.subplots()
ax.violinplot(df[['trestbps','thalach']].to_numpy())
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2d7978bbfa0>,
#   <matplotlib.collections.PolyCollection at 0x2d7978cf3a0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2d7978bbe80>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2d7978cfa90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2d7978cfe80>}

# %%
fig, ax = plt.subplots()
ax.violinplot(df[['trestbps','thalach']].to_numpy(),bw_method = 0.2)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2d79794a7c0>,
#   <matplotlib.collections.PolyCollection at 0x2d79794ab80>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2d79794a6a0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2d7979592b0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2d7979596a0>}

# %% [markdown]
# # Bee swarm plots

# %%
sb.swarmplot(data=df[['trestbps','thalach']],size=3)
# Out:
# <AxesSubplot:>

# %%
sb.violinplot(data=df[['trestbps','thalach']],inner='quartile',bw=0.2)
sb.swarmplot(data=df[['trestbps','thalach']],size=2, color='k',alpha=0.2)
# Out:
# <AxesSubplot:>
